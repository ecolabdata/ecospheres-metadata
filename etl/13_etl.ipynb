# %% [markdown]
# # Pipeline de traitement des données (du DUMP à la base de données)
#
# Permet d'extraire, transformer et charger les données issues du dump des fichiers json-ld (s3 MinIO) jusqu'à la base de donnée (postgres)
#
# ## Entrées
# Il faut avoir accès au S3 avec les fichier et copier dans le notebook la ligne de connexion (ligne disponible dans votre profil SSP Cloud -> Profil -> Connexion au Stockage -> Python (S3FS)
#
# Ce bucket s3 est disponible au sein du projet **projet-ecolab-action-qualite**.
# ## Sortie
# Remplit une base de données POSTGRESQL dont les identifiants sont lu depuis un fichier .env
#
# ```
# POSTGRES_URL=....
# POSTGRES_DB=...
# POSTGRES_USER=...
# POSTGRES_PASSWORD=...
# ```
# ## Visualisation
# La base de données est connectée à une instance de Superset.

# %% [markdown]
# ## Imports

# %%
import rdflib
import time
import pandas as pd
import os
import s3fs
import logging
import glob
import json

from dotenv import load_dotenv
from unidecode import unidecode
#from ydata_profiling import ProfileReport
from utils.dcat_reader_ckan import CatalogReader, DatasetReader
from utils.utils import create_universe_pprn

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Lecture du dump

# %%
# Create filesystem object
S3_ENDPOINT_URL = "https://" + os.environ["AWS_S3_ENDPOINT"]

# Enter S3 cmd copied form SSLab : 
fs = s3fs.S3FileSystem(client_kwargs={'endpoint_url': 'https://'+'minio.lab.sspcloud.fr'},key ='N8E5CECEX61XHVSJOEMS', secret = 'c6giCDWYEQ2bL9E19n4AGCExbPeh3lRu+Lm8D+kl', token = 'eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.....xdEBBAO2w1L8GwO4Gl-wC78MGXwxHy548LEVgAV2R89Hc0c4UUs7c66PYf6ZjhWSvlu-ZI1Lsacdi6IGBC0v0w')
#######

datasets = []
catalogs = []
iteration = 0
BUCKET = "projet-ecolab-action-qualite"
FILE_KEY_S3 = "DUMP_INTEGRATION_JSON/integration_page_107_2023-10-14.json"
FILE_PATH_S3 = BUCKET + "/" + FILE_KEY_S3


print(len(fs.ls(BUCKET + '/DUMP_INTEGRATION_JSON')))
      
for graph in fs.ls(BUCKET + '/DUMP_INTEGRATION_JSON')[0:10]:
    if '.json' in graph:
        with fs.open(graph, mode="rb") as file_in:
            read_data = file_in.read()
            page_datasets = DatasetReader(read_data).get_data()
            logging.debug("Fichier: ", graph, "- Nombre de datasets : ", len(datasets))
            datasets.append(
                page_datasets
            )
            iteration += 1

logging.debug("Nombre de pages traitées : ", iteration)
data = pd.concat(datasets)

display(data)
# Out:
# 239
#                                               dataset  \
# 0   http://catalogue.geo-ide.developpement-durable...
# 1   http://catalogue.geo-ide.developpement-durable...
# 2   http://catalogue.geo-ide.developpement-durable...
# 3   http://catalogue.geo-ide.developpement-durable...
# 4   http://catalogue.geo-ide.developpement-durable...
# ..                                                ...
# 41  http://catalogue.geo-ide.developpement-durable...
# 42  http://catalogue.geo-ide.developpement-durable...
# 43  http://catalogue.geo-ide.developpement-durable...
# 44  http://catalogue.geo-ide.developpement-durable...
# 45  http://catalogue.geo-ide.developpement-durable...
#
#                                                 title  \
# 0   Document d'urbanisme applicable par commune 20...
# 1   Zone de bruit d’une carte de bruit stratégique...
# 2   Zonage réglementaire du Plan de Prévention des...
# 3   Statut des numérisations des Documents d'Urban...
# 4   Zones multi-aléas dans les cas du Plan de Prév...
# ..                                                ...
# 41  Plan local d'urbanisme de la commune de Bouvai...
# 42  Plan local d'urbanisme de la commune de Mareui...
# 43  Plan local d'urbanisme de la commune de Viller...
# 44  Périmètre informatif du PLU de la commune de M...
# 45  Plan local d'urbanisme de la commune de Montdi...
#
#                                           description modification  \
# 0   Ce jeu de données recense les documents d'urba...   2023-02-03
# 1   Les zones de bruit sont des éléments géométriq...   2022-05-04
# 2                        PPR approuvé le 10 août 2021   2021-12-17
# 3   Pour chaque commune 2015 est précisé l'état de...   2023-02-03
# 4   Table non géométrique à utiliser pour décrire ...   2018-11-13
# ..                                                ...          ...
# 41  Le présent standard de données COVADIS concern...         None
# 42  Le présent standard de données COVADIS concern...         None
# 43  Le présent standard de données COVADIS concern...         None
# 44  Les informations surfaciques, linéaires ou pon...   2013-02-13
# 45  Le présent standard de données COVADIS concern...         None
#
#                                       right_statement  \
# 0   Aucun des articles de la loi ne peut être invo...
# 1   Pas de restriction d'accès public selon INSPIR...
# 2   Pas de restriction d'accès public selon INSPIR...
# 3   Pas de restriction d'accès public selon INSPIR...
# 4   Pas de restriction d'accès public selon INSPIR...
# ..                                                ...
# 41  Aucun des articles de la loi ne peut être invo...
# 42  Pas de restriction d'accès public selon INSPIR...
# 43  Pas de restriction d'accès public selon INSPIR...
# 44  Pas de restriction d'accès public selon INSPIR...
# 45  Aucun des articles de la loi ne peut être invo...
#
#                                                themes  \
# 0   http://registre.data.developpement-durable.gou...
# 1   http://registre.data.developpement-durable.gou...
# 2   http://registre.data.developpement-durable.gou...
# 3   http://registre.data.developpement-durable.gou...
# 4   http://registre.data.developpement-durable.gou...
# ..                                                ...
# 41  http://registre.data.developpement-durable.gou...
# 42  http://registre.data.developpement-durable.gou...
# 43  http://registre.data.developpement-durable.gou...
# 44  http://registre.data.developpement-durable.gou...
# 45  http://registre.data.developpement-durable.gou...
#
#                                             key_words standard creator  \
# 0   Aménagement Urbanisme/Zonages Planification pl...     None    None
# 1   bruit données ouvertes Nuisance/Bruit environn...     None    None
# 2      données ouvertes Risque/Zonages Risque naturel     None    None
# 3   urbanisme données ouvertes plu planification A...     None    None
# 4   pprt risque technologique plan de prévention m...     None    None
# ..                                                ...      ...     ...
# 41  données ouvertes plu Aménagement Urbanisme/Zon...     None    None
# 42  document d'urbanisme Usage des sols données ou...     None    None
# 43  Usage des sols données ouvertes plu usage des ...     None    None
# 44  mareuil-caubert document d'urbanisme Usage des...     None    None
# 45  Usage des sols données ouvertes montdidier plu...     None    None
#
#        status           catalog
# 0        None  GéoIDE Catalogue
# 1   Completed  GéoIDE Catalogue
# 2        None  GéoIDE Catalogue
# 3        None  GéoIDE Catalogue
# 4        None  GéoIDE Catalogue
# ..        ...               ...
# 41       None  GéoIDE Catalogue
# 42       None  GéoIDE Catalogue
# 43       None  GéoIDE Catalogue
# 44       None  GéoIDE Catalogue
# 45       None  GéoIDE Catalogue
#
# [820 rows x 11 columns]

# %%
catalogs = []
for catalog in data.dataset.unique():
    if catalog.split('.fr')[0] not in catalogs:
     catalogs.append(catalog.split('.fr')[0])

# %%
df = data.merge(cat, how='left', left_on='isPrimaryTopicOF', right_on='catalog_records')

# %% [markdown]
# ## Attribution des univers

# %%
def create_universe_pprn(row):
    """
    For a specific row, return if the element is considered to be a part of the 'PPRN' universe
    """
    for elem in ['title', 'description']:
        if 'pprn' in row[elem].lower():
            return 'PPRN'
        elif 'prevention des risques' in unidecode(row[elem]).lower():
            return 'PPRN'
    return None

# %%
data['univers'] = data.apply(create_universe_pprn, axis=1)

# %%
2357 PPRN avec filtre title = PPRN
3985 PPRN en ajoutant le filtre title = 'prevention des risques' (independament des accents et majuscules)
5122 PPRN en appliquant également ces filtre au champ 'description'

# %% [markdown]
# ## Export vers POSTGRES

# %%
from sqlalchemy import create_engine
engine = create_engine(f"postgresql+psycopg2://{os.environ['POSTGRES_USER']}:{os.environ['POSTGRES_PASSWORD']}@{os.environ['POSTGRES_URL']}:{os.environ['POSTGRES_PORT']}/{os.environ['POSTGRES_DB']}")

with engine.begin() as connection:
    data.to_sql(name='datasets', con=connection, if_exists='replace', index=False)

# %% [markdown]
# ## Création du describe() en ligne

# %%
import sweetviz as sv

my_report = sv.analyze(data)
my_report.show_html() # Default arguments will generate to "SWEETVIZ_REPORT.html"
